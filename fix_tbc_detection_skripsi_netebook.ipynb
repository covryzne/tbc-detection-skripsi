# %% [markdown]
# <a href="https://colab.research.google.com/github/covryzne/tbc-detection-skripsi/blob/main/fix_tbc_detection_skripsi_netebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Deteksi Penyakit Tuberkulosis pada Citra X-Ray Dada Menggunakan Densenet121**

# %% [markdown]
# ## **Latar Belakang**
# **`Tuberkulosis (TB)`** adalah penyakit menular yang disebabkan oleh bakteri **`Mycobacterium tuberculosis`**, yang terutama menyerang paru-paru dan dapat menyebar melalui udara. **`Menurut Global Tuberculosis Report 2024`**, estimasi jumlah orang yang terdiagnosis TB secara global mencapai `10,8` juta kasus di tahun `2023`. Ini mencerminkan peningkatan yang kecil dari 10,7 juta kasus di tahun 2022, meskipun tetap lebih tinggi daripada 10,4 juta kasus pada tahun 2021 dan 10,1 juta pada tahun 2020 [![WHO TB Report](https://img.shields.io/badge/WHO-TB%20Report-blue?logo=world-health-organization)](https://iris.who.int/bitstream/handle/10665/379339/9789240101531-eng.pdf?sequence=1)
#
# Dari total kasus TB global, delapan negara menyumbang lebih dari dua pertiga kasus, dengan **`Indonesia`** berada di **`peringkat kedua`** setelah India, menyumbang 10% dari total kasus global. [![WHO TB Report](https://img.shields.io/badge/WHO-TB%20Report-blue?logo=world-health-organization)](https://www.who.int/teams/global-tuberculosis-programme/tb-reports/global-tuberculosis-report-2023/tb-disease-burden/1-1-tb-incidence?)
#
# Di tingkat nasional, Kementerian Kesehatan Indonesia melaporkan bahwa pada tahun 2022, Indonesia memiliki 969.000 kasus TB yang dilaporkan, dengan cakupan pengobatan mencapai 71%. Dari jumlah tersebut, 55% pasien adalah laki-laki, 33% perempuan, dan 12% anak-anak (usia 0–14 tahun). [![Indonesia TB Report](https://img.shields.io/badge/KemenkesRI-TB%20Report-green)](https://tbindonesia.or.id/wp-content/uploads/2023/09/Laporan-Tahunan-Program-TBC-2022.pdf)
#
# Peningkatan kasus TB ini menunjukkan perlunya inovasi dalam metode deteksi dan diagnosis untuk mengendalikan penyebaran penyakit. Deteksi dini yang akurat sangat penting untuk memastikan pengobatan yang efektif dan mencegah penularan lebih lanjut.
#
# ## **Permasalahan dan Solusi**
# Tuberkulosis (TB) masih menjadi masalah kesehatan global, termasuk di Indonesia, yang menempati peringkat kedua dengan jumlah kasus TB tertinggi di dunia setelah India. Metode konvensional dalam mendeteksi TB, seperti pemeriksaan dahak dan tes tuberkulin, memiliki keterbatasan dalam hal kecepatan dan akurasi. Sementara itu, deteksi menggunakan X-ray dada menjadi alternatif yang lebih cepat, tetapi interpretasinya masih bergantung pada keahlian dokter radiologi, yang dapat menyebabkan subjektivitas dalam diagnosis.
#
# Untuk mengatasi tantangan ini, penelitian ini mengadopsi pendekatan Deep Learning berbasis Convolutional Neural Network (CNN) sebagai solusi untuk mendeteksi TB secara otomatis melalui gambar X-ray. CNN telah banyak digunakan dalam bidang medis karena kemampuannya dalam mengenali pola kompleks pada citra medis dengan akurasi tinggi.
#
# ### **Mengapa Menggunakan DenseNet121?**
# Dalam penelitian ini, dipilih DenseNet121 sebagai model utama karena memiliki efisiensi parameter yang lebih baik, aliran informasi yang lebih optimal, dan akurasi tinggi dalam klasifikasi gambar medis. Tidak seperti CNN konvensional, DenseNet121 menggunakan Densely Connected Layers, di mana setiap layer menerima input dari semua layer sebelumnya. Arsitektur ini mengurangi **`vanishing gradient`**, memungkinkan pemanfaatan ulang fitur, dan meningkatkan ekstraksi fitur tanpa redundansi.
#
# Selain itu, DenseNet121 memiliki jumlah parameter yang lebih sedikit dibandingkan arsitektur lain seperti ResNet atau VGG, sehingga lebih ringan, mempercepat proses training, dan mengurangi risiko overfitting. Model ini juga telah terbukti efektif dalam klasifikasi penyakit paru-paru, termasuk TB, menjadikannya pilihan yang tepat untuk mendukung sistem deteksi otomatis TB dalam penelitian ini.
#
# Dengan adanya sistem berbasis DenseNet121, diharapkan proses skrining TB dapat dilakukan lebih cepat dan akurat, sehingga dapat membantu tenaga medis dalam mendeteksi TB sejak dini. Namun, sistem ini tetap digunakan **`sebagai alat bantu dan bukan pengganti diagnosis dari dokter spesialis.`**
#
# ## **Dataset yang Digunakan**
# Dalam penelitian ini, digunakan dataset Tuberculosis (TB) Chest X-ray dari Kaggle yang bisa diakses pada link dibawah ini:
#
# [![Indonesia TB Report](https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=Kaggle&logoColor=white)](https://www.kaggle.com/datasets/tawsifurrahman/tuberculosis-tb-chest-xray-dataset)
#
# [![Mendeley Data](https://img.shields.io/badge/Mendeley-FF4C4C?style=for-the-badge&logo=Mendeley&logoColor=white)](https://data.mendeley.com/datasets/8j2g3csprk/2)
#
# dataset terdiri dari:
#   - 700 gambar X-ray positif TB
#   - 3.500 gambar X-ray normal <br>
#
# Dataset ini akan digunakan untuk melatih model DenseNet121, sebuah arsitektur CNN yang telah terbukti memiliki performa tinggi dalam klasifikasi gambar medis.
#
# ## **Tujuan Penelitian**
# Penelitian ini bertujuan untuk membangun sistem TB Detector menggunakan DenseNet121 yang mampu mendeteksi indikasi TB pada X-ray dada secara otomatis. Sistem ini diharapkan dapat membantu dalam proses skrining awal TB. Namun, hasil deteksi tetap harus dikonfirmasi oleh dokter spesialis untuk diagnosis yang lebih akurat.
#
# Dengan adanya teknologi ini, diharapkan dapat meningkatkan efektivitas deteksi dini TB, terutama di daerah dengan keterbatasan akses terhadap tenaga medis.

# %% [markdown]
# ## **Setup GPU dan Install Library**

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install torchmetrics --no-deps
# !pip install lightning-utilities
# !pip install onnx
# !pip install onnxruntime
# !pip install gdown
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 79.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 105.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 834.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Import Libraries**

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import shutil
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import seaborn as sns
import torchmetrics
import torch.onnx
import torchvision.transforms as transforms
import onnxruntime as ort
import torchvision.models as models

from tqdm import tqdm
from pathlib import Path
from google.colab import files
from PIL import Image
from sklearn import metrics
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from torchvision.io import read_image
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchvision.models import densenet121,DenseNet121_Weights, DenseNet
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from torchmetrics.classification import BinaryAccuracy, BinaryAUROC, BinaryF1Score
from mlxtend.plotting import plot_confusion_matrix

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
print(torch.backends.cudnn.version())
# Out:
# 2.7.1+cu118
# True
# Tesla T4
# 11.8
# 90100

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Buat tensor besar
x = torch.randn(10000, 10000, device=device)

# Coba operasi di GPU
start = time.time()
y = torch.matmul(x, x)
torch.cuda.synchronize()  # Sinkronisasi untuk timing yang akurat
end = time.time()

print(f"GPU computation time: {end - start:.4f} seconds")
# Out:
# GPU computation time: 0.6085 seconds

# %%
print(torch.__version__)  # Pastikan versinya 2.0.1+cu118
print(torch.cuda.is_available())  # Harusnya True
print(torch.cuda.get_device_name(0))  # Pastikan tetap Tesla T4
# Out:
# 2.7.1+cu118
# True
# Tesla T4

# %% [markdown]
# ## **Konfigurasi Awal Menggunakan Teknik Seed Reproducibility**
# Menggunakan **`seed reproducibilty`** dikarenakan agar hasil eksperimen tidak berubah tiap kali dijalankan (misalnya inisialisasi bobot model, shuffling data, dll.).

# %%
SEED = 1234

def set_seeds(seed=1234):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seeds(seed=SEED)

cuda = True
device = torch.device("cuda" if (
    torch.cuda.is_available() and cuda) else "cpu")

print(device)
# Out:
# cuda

# %%
print(torch.version.cuda)  # Harusnya 12.4
print(torch.cuda.is_available())  # Harusnya True
print(torch.cuda.get_device_name(0))  # Harusnya Tesla T4
# Out:
# 11.8
# True
# Tesla T4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Buat tensor besar
x = torch.randn(10000, 10000, device=device)

# Coba operasi di GPU
start = time.time()
y = torch.matmul(x, x)
torch.cuda.synchronize()  # Sinkronisasi untuk timing yang akurat
end = time.time()

print(f"GPU computation time: {end - start:.4f} seconds")
# Out:
# GPU computation time: 0.5409 seconds

# %% [markdown]
# ## **Data Preparation**
#
# Pada tahap ini, menggunakan dataset X-ray Tuberkulosis (TB) yang diperoleh dari sumber terpercaya, yaitu Kaggle. Dataset ini kemudian diorganisir dalam struktur direktori sebagai berikut:
#
# ```
#   - datasets
#     |- normal
#     |- tuberculosis
# ```

# %% [markdown]
# ### **Import Dataset**

# %%
# !gdown --id 1kJbwjJsw962QbPx6lA1hY8gk9zIJlGC1 -O TB_Chest_Radiography_Database.zip
# !gdown --id 1Zq2Qb5wSov3m7cf9OKLYOgZgUhLjb2XN -O Dataset_of_Tuberculosis_Chest_Xrays_Images.zip

# !unzip -q TB_Chest_Radiography_Database.zip
# !unzip -q Dataset_of_Tuberculosis_Chest_Xrays_Images.zip
# !rm TB_Chest_Radiography_Database.zip
# !rm Dataset_of_Tuberculosis_Chest_Xrays_Images.zip

# !mkdir -p datasets/ori/normal datasets/ori/tuberculosis datasets/splitting

# !cp -r TB_Chest_Radiography_Database/Normal/* datasets/ori/normal/
# !cp -r Dataset_of_Tuberculosis_Chest_Xrays_Images/'Normal Chest X-rays'/* datasets/ori/normal/

# !cp -r TB_Chest_Radiography_Database/Tuberculosis/* datasets/ori/tuberculosis/
# !cp -r Dataset_of_Tuberculosis_Chest_Xrays_Images/'TB Chest X-rays'/* datasets/ori/tuberculosis/

# !rm -rf TB_Chest_Radiography_Database
# !rm -rf Dataset_of_Tuberculosis_Chest_Xrays_Images
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1kJbwjJsw962QbPx6lA1hY8gk9zIJlGC1
# From (redirected): https://drive.google.com/uc?id=1kJbwjJsw962QbPx6lA1hY8gk9zIJlGC1&confirm=t&uuid=1a77d403-f863-4567-b124-373cdaaa7e8f
# To: /content/TB_Chest_Radiography_Database.zip
# 100% 696M/696M [00:10<00:00, 68.1MB/s]
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Zq2Qb5wSov3m7cf9OKLYOgZgUhLjb2XN
# ...

# %% [markdown]
# Setelah melakukan download dan unzip folder, saya melakukan penyesuaian direktori yang akan dibutuhkan yaitu di
#
# ```
#   - datasets
#     |- normal
#     |- tuberculosis
# ```

# %% [markdown]
# Karena dataset gambar sudah dilengkapi dengan informasi metadata dalam file .xlsx, langkah pertama yang saya lakukan adalah memeriksa dataset melalui file tersebut. Pemeriksaan ini untuk memastikan data sudah lengkap, memahami distribusi kelas (Normal vs Tuberculosis), serta mengidentifikasi potensi masalah seperti duplikasi atau data yang hilang sebelum masuk ke tahap preprocessing dan pelatihan model.

# %%
# Cek datasets
normal_files = os.listdir("/content/datasets/ori/normal")
tb_files = os.listdir("/content/datasets/ori/tuberculosis")

# %%
print("-------------------Dataset------------------")
print("Total Normal CXR Images: ",len(normal_files))
print("Total Tuberculosis CXR Images: ",len(tb_files))
# Out:
# -------------------Dataset------------------
# Total Normal CXR Images:  4014
# Total Tuberculosis CXR Images:  3194

# %% [markdown]
# Dataset tidak seimbingan `(unbalance data)` maka dilakukan teknik penyeimbangan data `(balancing data)` menggunakan teknik `undersampling`

# %%
normal_dir = "/content/datasets/ori/normal"
target_count = 3194

# Ambil semua file dari folder normal
normal_files = os.listdir(normal_dir)

# Hitung jumlah file yang harus dihapus
files_to_remove = len(normal_files) - target_count

# Cek kalau file normal lebih banyak dari target
if files_to_remove > 0:
    # Acak file dan pilih yang mau dihapus
    random.shuffle(normal_files)
    files_for_deletion = normal_files[:files_to_remove]

    # Hapus file
    for file in files_for_deletion:
        os.remove(os.path.join(normal_dir, file))

# %% [markdown]
# ### **Splitting Dataset**
# Untuk memastikan model dapat belajar dengan optimal dan dievaluasi dengan baik, dataset dibagi menjadi tiga bagian yaitu:
#
# 1. **`Training Set`** -> Digunakan untuk melatih model.
# 2. **`Validation Set`** -> Digunakan untuk menyetel hyperparameter dan menghindari overfitting.
# 3. **`Test Set`** -> Digunakan untuk menguji model pada data yang belum pernah dilihat sebelumnya.
#
# Disini saya menggunakan split data dengan rasio `70 (train)` : `15 (validation)` : `15 (test)`

# %%
# Path Dataset Awal (dari folder "ori")
normal = glob.glob("datasets/ori/normal/*")
tb = glob.glob("datasets/ori/tuberculosis/*")

# Gabungkan semua data
all_images = normal + tb
all_labels = [0] * len(normal) + [1] * len(tb)  # Label: 0 = Normal, 1 = TB

# Split Train (70%) dan Sisa (30%)
train_path, temp_images, train_labels, temp_labels = train_test_split(
    all_images, all_labels, test_size=0.3, random_state=42, stratify=all_labels
)

# Split Sisa menjadi Validation (15%) dan Test (15%)
val_path, test_path, val_labels, test_labels = train_test_split(
    temp_images, temp_labels, test_size=0.5, random_state=42, stratify=temp_labels
)

# Folder penyimpanan hasil split di dalam "splitting/"
base_dir = "datasets/splitting"
split_dirs = ["train", "val", "test"]

# Buat folder train, val, test
for split in split_dirs:
    os.makedirs(os.path.join(base_dir, split), exist_ok=True)

# Fungsi untuk menyalin file ke folder split
def copy_images(image_paths, split):
    for img_path in image_paths:
        dst_path = os.path.join(base_dir, split, os.path.basename(img_path))
        shutil.copy(img_path, dst_path)

# Salin gambar ke folder yang sesuai
copy_images(train_path, "train")
copy_images(val_path, "val")
copy_images(test_path, "test")

# Cek jumlah data
print("-------------------datasets/spliting------------------")
print(f"Total train CXR Images: {len(train_path)}")
print(f"Total val CXR Images: {len(val_path)}")
print(f"Total test CXR Images: {len(test_path)}")
# Out:
# -------------------datasets/spliting------------------
# Total train CXR Images: 4471
# Total val CXR Images: 958
# Total test CXR Images: 959

# %% [markdown]
# ### **Imbalanced Data**

# %%
print("Train Labels:", train_labels.count(0), train_labels.count(1))
print("Validation Labels:", val_labels.count(0), val_labels.count(1))
print("Test Labels:", test_labels.count(0), test_labels.count(1))
# Out:
# Train Labels: 2235 2236
# Validation Labels: 479 479
# Test Labels: 480 479

# %% [markdown]
# Meskipun data telah dibagi ke dalam `set train, validation, dan test`, hasilnya masih menunjukkan ketidakseimbangan kelas **`(imbalanced dataset)`**. Jumlah sampel pada kelas Normal jauh lebih banyak dibandingkan dengan kelas Tuberculosis (TB).
#
# Akan menyebabkan model cenderung lebih sering memprediksi kelas mayoritas `(Normal)` dan kurang peka terhadap kelas minoritas `(TB)`.
#
# Oleh karena itu, diperlukan strategi tambahan, seperti pemberian `**class weight**` pada loss function, untuk mengatasi bias ini dan memastikan model dapat mengenali pola dari kedua kelas dengan lebih baik.

# %%
Image.open(train_path[765])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# Setelah melakukan splitting data menjadi 3 bagian yaitu `train, validation dan test` dengan rasio `70:15:15` dan telah mengecek secara random dataset yang termasuk pada train, maka selanjutnya akan dilakukan `preprocessing data`

# %% [markdown]
# ## **Data Preprocessing**
#
# Pada tahap ini, dilakukan preprocessing dataset dengan mendefinisikan pipeline transformasi gambar menggunakan `PyTorch's transforms module`.
#
# Tujuan preprocessing adalah untuk menyamakan ukuran gambar, meningkatkan variasi data, dan memastikan format gambar sesuai dengan model yang akan digunakan.

# %% [markdown]
# ### **Data Augmentation**
#
# Melakukan data augmentation dengan cara transformasi data untuk memastikan bahwa semua gambar memiliki ukuran dan format yang sama, serta siap digunakan sebagai input untuk model. Sebelum masuk ke transformation data, saya mau cek untuk format dari imagenya, rgb atau grayscale, meskipun dengan kasat mata terlihat grayscale belum berarti grayscale apabila belum dicek.

# %%
img = Image.open("/content/datasets/ori/normal/Normal-100.png")
img_array = np.array(img)

print(img_array.shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# dikarenakan hasilnya adalah (512, 512, 3) maka berarti terdapat image yang RGB, berarti untuk tranformation saya menggunakan ketentuan transformation untuk RGB. dimana menggunakan normalize yang berasal dari mean dan std nya

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.Grayscale(num_output_channels=1),  # Ubah ke grayscale
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]) # Normalisasi untuk grayscale
    ]),
    'others': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.Grayscale(num_output_channels=1),  # Ubah ke grayscale
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]) # Normalisasi untuk grayscale
    ]),
}

# %% [markdown]
# Beberapa tahap transformasi yang saya lakukan adalah:
# 1. `Resize` -> Menyesuaikan ukuran gambar agar seragam.
# 2. `Random Rotation & Flipping` -> Augmentasi data untuk meningkatkan generalisasi model.
# 3. `Center Cropping` -> Memotong bagian tengah gambar untuk fokus ke area penting.
# 4. `Convert to Tensor` -> Mengubah gambar ke format tensor agar dapat diproses oleh PyTorch.
# 5. `Normalization` -> Menyesuaikan nilai piksel menggunakan mean & standar deviasi dataset, agar distribusi data lebih stabil.

# %% [markdown]
# Setelah melakukan data transfomation, saya membuat class bernama `TB_CXR_Dataset` yang berfungsi untuk memuat dan mengelola dataset gambar X-ray yang digunakan untuk menerima daftar path gambar sebagai input dan secara otomatis menetapkan **`label=0`** untuk **`normal`** dan **`label=1`** untuk **`tuberculosis`**. Selain itu, `TB_CXR_Dataset` juga digunakan untuk menerapkan transformasi gambar yang telah didefinisikan sebelumnya untuk preprocessing data.

# %%
img = Image.open("/content/datasets/ori/normal/Normal-100.png")
img_transformed = data_transforms['train'](img)
print(img_transformed.shape)  # Harusnya jadi (1, 224, 224)
# Out:
# torch.Size([1, 224, 224])

# %%
class TB_CXR_Dataset(Dataset):
    def __init__(self, images, transform=None):
        self.img_paths = images
        self.img_labels = [0 if "normal" in img else 1 for img in self.img_paths]
        self.transform = transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        # get the image path and label for the specified index
        img_path = self.img_paths[idx]
        label = self.img_labels[idx]

        # load the image from the path
        image = Image.open(img_path)
        # image = image.convert("RGB")
        image = image.convert("L") # Convert to grayscale/ 'L' for 8 bit pixels, black and white

        # Apply transformasi kalau ada
        if self.transform:
            image = self.transform(image)

        # return the image and label as a tuple
        return image, label

# Dataset for train, valid and test
train_data = TB_CXR_Dataset(train_path, transform = data_transforms["train"])
valid_data = TB_CXR_Dataset(val_path, transform = data_transforms["others"])
test_data = TB_CXR_Dataset(test_path, transform = data_transforms["others"])

# Dataloader for train, valid and test
train_dataloader = DataLoader(train_data, batch_size=32, shuffle=True)
valid_dataloader = DataLoader(valid_data, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=32, shuffle=True)

# %% [markdown]
# step ini saya lakukan supaya dataset bisa dibaca dengan lebih rapi dan efisien dalam bentuk DataLoader

# %% [markdown]
# ## **Data Visualization**
#
# Sebelum masuk ke modelling saya ingin melihat distribusi dari datasetnya dulu biar tahu apakah data balance atau tidak. Ini penting, karena kalau data nggak seimbang, model bisa cenderung bias ke kelas mayoritas.

# %% [markdown]
# ### **Distribution Normal vs TBC class**

# %%
normal_size = len(normal_files)
Tuberculosis_size = len(tb_files)
sizes = [normal_size, Tuberculosis_size]

plt.bar(['Normal', 'Tuberculosis'], sizes)

plt.xlabel('Dataset type')
plt.ylabel('Number of data points')
plt.title('Normal vs Tuberculosis Class')

plt.show()

# %% [markdown]
# ### **Distribution train, validation dan test dataset**

# %%
train_size = len(train_data)
valid_size = len(valid_data)
test_size = len(test_data)

sizes = [train_size, valid_size, test_size]

plt.bar(['train', 'valid', 'test'], sizes)

plt.xlabel('Dataset type')
plt.ylabel('Number of Data Points')
plt.title('train, validation and test dataset')

plt.show()

# %% [markdown]
# ### **Visualize Sampel Data**

# %%
data, labels = next(iter(train_dataloader))

fig, axs = plt.subplots(nrows=3, ncols=5,figsize=(20, 12))

for i, ax in enumerate(axs.flat):
    image, label = data[i], labels[i]
    img = image.numpy().transpose((1, 2, 0))
    """
    Untuk kebutuhan visualize tidak dilakukan normalize
    """
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean
    img = np.clip(img, 0, 1)

    ax.imshow(img)
    ax.set_title(f"Label: {label.item()}", fontsize=12)

plt.show()

# %%
# prompt: buatkan kode untuk menunjukkan perbedaan salah satu data image yang sudah dilakukan augmentasi dan belum sesuai apa yang sudah saya lakukan di cell augmentation data

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Load an image from the training set
image_path = train_path[789]  # Example: Accessing the 766th image in train_path
original_image = Image.open(image_path)

# Apply the transformation
transformed_image = data_transforms['train'](original_image)

# Convert the transformed tensor image back to a PIL image for display
transformed_image_np = transformed_image.numpy().transpose((1, 2, 0))

# Denormalize the image (assuming normalization was done in the transforms)
mean = np.array([0.5])
std = np.array([0.5])
transformed_image_np = std * transformed_image_np + mean
transformed_image_np = np.clip(transformed_image_np, 0, 1)

# Display both images
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(original_image, cmap='gray') # Ensure original is displayed as grayscale
axes[0].set_title("Original Image")

axes[1].imshow(transformed_image_np, cmap='gray') # Ensure transformed is displayed as grayscale
axes[1].set_title("Transformed Image")

plt.show()

# %% [markdown]
# ## **DenseNet121 Architecture**
# Sebelum masuk ke tahap training model, saya menggunakan pretrained model DenseNet121. Karena saya tidak melatih model dari nol, melainkan memanfaatkan arsitektur DenseNet121 yang sudah dilatih sebelumnya di dataset ImageNet. Karena model ini sudah memiliki pemahaman dasar tentang pola visual.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class CXR_DenseNetModel(nn.Module):
    """DenseNet121 pretrained model for chest X-ray (grayscale)."""
    def __init__(self, num_classes):
        super(CXR_DenseNetModel, self).__init__()

        self.model = models.densenet121(pretrained=True)

        # Ubah first convolution layer untuk menerima input grayscale (1 channel)
        self.model.features.conv0 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

        # Freeze semua parameter kecuali classifier
        for param in self.model.parameters():
            param.requires_grad = False

        # Atur ulang classifier
        in_features = self.model.classifier.in_features
        self.model.classifier = nn.Sequential(
            nn.Linear(in_features, in_features // 2),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(in_features // 2, in_features // 4),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(in_features // 4, in_features // 8),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(in_features // 8, num_classes),
        )

    def forward(self, x):
        return self.model(x)

# %%
# Inisialisasi model dengan 2 kelas (TB vs Normal)
model = CXR_DenseNetModel(num_classes=2)
model = model.to(device)
model
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 101MB/s]
# CXR_DenseNetModel(
#   (model): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %% [markdown]
# Setelah melakukan build architecture `DenseNet121`, makan next step yang saya lakukan adalah melakukan training model DenseNet121, tapi sebelum melakukan training model masih terdapat **`data imbalance`** yang belum dilakukan.
#
# maka disini saya akan melakukan class weight untuk mengatasi masalah ini, saya akan menghitung class weight dan menggunakannya dalam loss function selama training.
#
# Dengan class weight, model akan memberikan bobot lebih besar ke kelas `minoritas (TB)`, sehingga tetap bisa mengenali pola dengan baik.
#
# Data imbalance: <br>
# `Normal: 2450` <br>
# `TB: 491`

# %% [markdown]
# ### **Handling Imbalanced Data**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source: https://naadispeaks.blog/2021/07/31/handling-imbalanced-classes-with-weighted-loss-in-pytorch/

# %%
num_normal = len([label for label in train_labels if label == 0]) # 2450 normal
num_tb = len([label for label in train_labels if label == 1]) # 491 TB

total_samples = num_normal + num_tb

def compute_class_weight(class_count, total_count):
    return 1 - (class_count / total_count)

class_weights = torch.tensor([
    compute_class_weight(num_normal, total_samples),  # Class 0 (Normal)
    compute_class_weight(num_tb, total_samples)       # Class 1 (TB)
])

# %%
class_weights = class_weights.to(device)
print("Class Weights:", class_weights)
# Out:
# Class Weights: tensor([0.5001, 0.4999], device='cuda:0')

# %% [markdown]
# ## **Training Data**

# %%
# Define the Binary CrossEntropy with Logits loss function and Adam optimizer
loss_fn = nn.BCEWithLogitsLoss(weight = class_weights.to(device))
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
train_losses = []
valid_losses = []
train_acc = []
valid_acc=[]
# Define a function for the training loop
def train(model, loss_fn, optimizer, num_epochs):

    for epoch in tqdm(range(num_epochs)):

        # Training
        # Set the model to training mode
        model.train()

        train_size = 0
        train_loss = 0.0
        train_accuracy = 0.0

        # Loop through the training dataloader
        for batch_idx, (images, labels) in enumerate(train_dataloader):
            images, labels = images.to(device), labels.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = loss_fn(outputs, F.one_hot(labels,2).float())

            # Compute accuracy
            _, preds = torch.max(outputs, 1)
            train_accuracy += torch.sum(preds == labels.data)

            # Backward pass
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            train_size += images.size(0)

        # Validation
        # Set the model to evalutaion mode
        model.eval()

        valid_size = 0
        valid_loss = 0.0
        valid_accuracy = 0.0

        # Loop through the validing dataloader
        for batch_idx, (images, labels) in enumerate(valid_dataloader):
            images, labels = images.to(device), labels.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = loss_fn(outputs, F.one_hot(labels,2).float())

            # Compute accuracy
            _, preds = torch.max(outputs, 1)
            valid_accuracy += torch.sum(preds == labels.data)

            # Backward pass
            loss.backward()
            optimizer.step()

            valid_loss += loss.item() * images.size(0)
            valid_size += images.size(0)

        # Print training and validation statistics
        train_loss = train_loss / train_size
        train_losses.append(train_loss)
        train_accuracy = train_accuracy / train_size
        train_acc.append(train_accuracy)

        valid_loss = valid_loss / valid_size
        valid_losses.append(valid_loss)

        valid_accuracy = valid_accuracy / valid_size
        valid_acc.append(valid_accuracy)


        print(f"\nTrain Loss: {train_loss:.3f},Train Accuracy: {train_accuracy:.3f}, Valid Loss: {valid_loss:.3f}, Valid Accuracy: {valid_accuracy:.2f}")

# %%
# Train the model
train(model, loss_fn, optimizer, num_epochs=100)
# Out:
#   1%|          | 1/100 [00:49<1:21:25, 49.34s/it]
# Train Loss: 0.242,Train Accuracy: 0.751, Valid Loss: 0.118, Valid Accuracy: 0.90
#   2%|▏         | 2/100 [01:37<1:19:55, 48.93s/it]
# Train Loss: 0.175,Train Accuracy: 0.845, Valid Loss: 0.079, Valid Accuracy: 0.94
#   3%|▎         | 3/100 [02:26<1:18:35, 48.61s/it]
# Train Loss: 0.150,Train Accuracy: 0.873, Valid Loss: 0.075, Valid Accuracy: 0.94
#   4%|▍         | 4/100 [03:14<1:17:36, 48.50s/it]
# Train Loss: 0.151,Train Accuracy: 0.871, Valid Loss: 0.073, Valid Accuracy: 0.95
#   5%|▌         | 5/100 [04:02<1:16:41, 48.44s/it]
# Train Loss: 0.136,Train Accuracy: 0.890, Valid Loss: 0.071, Valid Accuracy: 0.95
#   6%|▌         | 6/100 [04:51<1:15:44, 48.35s/it]
# Train Loss: 0.130,Train Accuracy: 0.896, Valid Loss: 0.070, Valid Accuracy: 0.94
#   7%|▋         | 7/100 [05:39<1:15:00, 48.39s/it]
# Train Loss: 0.125,Train Accuracy: 0.899, Valid Loss: 0.049, Valid Accuracy: 0.96
#   8%|▊         | 8/100 [06:27<1:14:06, 48.33s/it]
# ...

# %%
# import shutil

# shutil.make_archive("/content/splitting", 'zip', "/content/datasets/splitting")

# %%
# from google.colab import files

# files.download("/content/splitting.zip")

# %% [markdown]
# ##**Metrics Evaluation**

# %% [markdown]
# ### **Evaluation Train and Validation**

# %%
# plot train and test losses
plt.plot(train_losses, label='train loss')
plt.plot(valid_losses, label='validation loss')
plt.legend()
plt.show()

# %%
# plot train and validation acc
train_acc_np= np.array([x.cpu().numpy() for x in train_acc])
valid_acc_np= np.array([x.cpu().numpy() for x in valid_acc])

plt.plot(train_acc_np, label='train accuracy')
plt.plot(valid_acc_np, label='validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Grafik menunjukkan model belajar dengan baik tanpa indikasi overfitting signifikan. `Train Loss` dan `Validation Loss` menurun seiring epoch, menandakan model mampu menggeneralisasi. Secara keseluruhan, model siap diuji lebih lanjut dengan `Confusion Matrix` atau `AUROC Curve` untuk memastikan kualitas prediksi.

# %% [markdown]
# ### **Evaluation Test**

# %%
# Evaluation on test set
y_true = []
y_hat = []

test_size = 0
test_loss = 0.0
test_accuracy = 0.0

# Set model ke eval mode
model.eval()

# Matikan gradient untuk mempercepat inferensi
with torch.no_grad():
    for images, labels in test_dataloader:
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = loss_fn(outputs, F.one_hot(labels, 2).float())

        # Compute accuracy
        _, preds = torch.max(outputs, 1)
        test_accuracy += torch.sum(preds == labels.data).item()

        y_true.extend(labels.cpu().numpy().tolist())
        y_hat.extend(preds.cpu().numpy().tolist())

        test_loss += loss.item() * images.size(0)
        test_size += images.size(0)

# Hitung rata-rata loss dan akurasi
test_loss /= test_size
test_accuracy /= test_size

print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Loss: 0.0384, Test Accuracy: 0.9729

# %% [markdown]
# ### **Evaluation Test Accuracy, AUROC dan F1 Score**

# %%
metrics_acc = BinaryAccuracy()
metric_auroc = BinaryAUROC(thresholds=None)
metric_f1 = BinaryF1Score()

target = torch.tensor(y_true)
preds = torch.tensor(y_hat)

# Accuracy
acc = metrics_acc(preds, target)

# AUROC
auroc = metric_auroc(preds, target)

# F1 Score
f1 = metric_f1(preds, target)

print("Test Accuracy: ", acc)
print("Test AUROC: ", auroc)
print("Test F1: ", f1)
# Out:
# Test Accuracy:  tensor(0.9729)
# Test AUROC:  tensor(0.9729)
# Test F1:  tensor(0.9730)

# %%
fpr, tpr, _ = metrics.roc_curve(y_true,  y_hat)
auc = metrics.roc_auc_score(y_true, y_hat)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### **Confussion Matrix**

# %%
conf_matrix = confusion_matrix(y_true, y_hat)
conf_matrix
# Out:
# array([[465,  15],
#        [ 11, 468]])

# %%
cm = confusion_matrix(y_true, y_hat)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# - True Positive (TP) – 88 pasien
# Pasien TB yang dideteksi sebagai TB
# - True Negative (TN) – 514 pasien
# Pasien sehat yang dideteksi sebagai sehat
# - False Positive (FP) – 11 pasien
# Pasien sehat tapi dikira TB
# - False Negative (FN) – 17 pasien
# Pasien TB tapi dikira sehat

# %% [markdown]
# ## **Classification Report**

# %%
target_names = ['normal', 'tuberculosis']
print(classification_report(y_true, y_hat, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.98      0.97      0.97       480
# tuberculosis       0.97      0.98      0.97       479
#
#     accuracy                           0.97       959
#    macro avg       0.97      0.97      0.97       959
# weighted avg       0.97      0.97      0.97       959

# %% [markdown]
# ## **Saved Model**

# %%
# create model directory path
MODEL_PATH = Path('/content/TBCsavedModel')

MODEL_PATH.mkdir(parents = True,
                 exist_ok = True)

# create model save
MODEL_NAME = 'tbc_model.pth'
MODEL_SAVE_PATH = MODEL_PATH/MODEL_NAME

# save the entire model
print(f'saving the entire model to :{MODEL_SAVE_PATH}')
torch.save(model, MODEL_SAVE_PATH)
# Out:
# saving the entire model to :/content/TBCsavedModel/tbc_model.pth

# %% [markdown]
# ### **ONNX Format**

# %%
import torch

# Tentukan device yang sama dengan model (dalam kasus ini CPU)
device = torch.device("cpu")
model.to(device)
model.eval()

# Buat input dummy di device yang sama
x = torch.randn(1, 1, 224, 224, requires_grad=True, device=device)

input_names = ["actual_input"]
output_names = ["output"]

torch.onnx.export(model,
                  x,
                  "/content/TBCsavedModel/savedModelTB.onnx",
                  verbose=False,
                  input_names=input_names,
                  output_names=output_names,
                  export_params=True)

# %% [markdown]
# ## **Load Model**

# %%
import torch
import numpy as np
import onnxruntime as ort
from PIL import Image
from torchvision import transforms
from google.colab import files

# Load PyTorch model
pth_model_path = "/content/TBCsavedModel/tbc_model.pth"

# explicitly set weights_only=False to load the entire model
model = torch.load(pth_model_path, map_location=torch.device("cpu"), weights_only=False)
model.eval()

# Load ONNX model
onnx_model_path = "/content/TBCsavedModel/savedModelTB.onnx"
ort_session = ort.InferenceSession(onnx_model_path)

# Define preprocessing transform (sama untuk PyTorch & ONNX)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # sesuai training
])

classes = ["Normal", "Tuberculosis"]

# %%
# === Inference dengan model PyTorch ===
img_path = "/content/datasets/splitting/test/Normal-2782.png"
img = Image.open(img_path)
input_tensor = transform(img).unsqueeze(0)

with torch.no_grad():
    output = model(input_tensor)
    _, predicted = torch.max(output, 1)

print(f"[PyTorch] Hasil Prediksi: {classes[predicted.item()]}")

# === Inference dengan model ONNX ===
img_path = "/content/datasets/splitting/test/Normal-2782.png"
img = Image.open(img_path)
input_tensor = transform(img).unsqueeze(0).numpy()

onnx_output = ort_session.run(None, {"actual_input": input_tensor})
predicted_class = np.argmax(onnx_output[0])

print(f"[ONNX] Hasil Prediksi: {classes[predicted_class]}")
# Out:
# [PyTorch] Hasil Prediksi: Normal
# [ONNX] Hasil Prediksi: Normal

# %%
import shutil

shutil.make_archive("/content/savedmodel", 'zip', "/content/TBCsavedModel")
# Out:
# '/content/savedmodel.zip'

# %%
from google.colab import files

files.download("/content/savedmodel.zip")
